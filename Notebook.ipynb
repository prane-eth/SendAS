# %% [markdown]
# <a href="https://colab.research.google.com/github/vh-praneeth/CyberSec_Project/blob/main/Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/vh-praneeth/Submarine_cable_route 2> /dev/null
# %cd Submarine_cable_route

# %% [markdown]
# ## Running code

# %%
# !java Main.java
